# %% [markdown]
# I want to see the effects of the new lr scheduling

# %%
# Add project root to path so we can import from data_manipulation and model
import sys
from pathlib import Path

def _find_project_root():
    cwd = Path.cwd()
    if (cwd / "data_manipulation").is_dir():
        return cwd
    if (cwd.parent / "data_manipulation").is_dir():
        return cwd.parent
    return cwd  # fallback

project_root = _find_project_root()
if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))

# %%
import torch
from torch import nn
import matplotlib.pyplot as plt
from functools import partial
import numpy as np


# Imports from data_manipulation and model
from data_manipulation.data_split import create_dataloader, DemandDataset
from model.functions import pinball_loss, rmse, train, get_test_loss, pinball_loss_tensor, pinball_loss_sum

# %%
class thread_net(nn.Module):

    @staticmethod
    def _mlp(sizes: list[int]) -> nn.Sequential:
        """Linear layers with ReLU between; no ReLU after the last linear."""
        if len(sizes) < 2:
            raise ValueError("layer_list needs at least [input_dim, output_dim]")
        layers: list[nn.Module] = []
        for i in range(len(sizes) - 1):
            layers.append(nn.Linear(sizes[i], sizes[i + 1]))
            if i < len(sizes) - 2:
                layers.append(nn.ReLU())
        return nn.Sequential(*layers)

    def __init__(self, layer_list=[12, 40, 40, 40, 1], num_nets=500):
        super().__init__()
        self.layer_list = list(layer_list)
        self.nets = nn.ModuleList(
            [self._mlp(self.layer_list) for _ in range(num_nets)]
        )
        self.num_nets = num_nets

    def forward(self, x):
        outs = [net(x[:, i::self.num_nets]) for i, net in enumerate(self.nets)]
        return torch.cat(outs, dim=1)

# %%
all_specs = [
    "sales",
    "7_day_rolling_ema",	
    "30_day_rolling_ema",
    "90_day_rolling_ema",
    "30_day_rolling_min",
    "5_day_lag",
    "6_day_lag",
    "7_day_lag",
    "dif_180_day",
]

# %%
# Get data for spec
train_loader, val_loader, test_loader = create_dataloader(
    batch_size=8, 
    test_batch_size=1,
    pin_memory=False,
    specs=all_specs,
    combine_items=True,
    combine_stores=True
    )

# %%
h_cost = 1
l_cost = 3
num_epochs = 500

# %%
num_nets = train_loader.dataset.y.shape[1]
in_per_net = train_loader.dataset.x.shape[1] // num_nets
layer_list = [in_per_net, 80, 80, 80, 1]

# %%
net_1 = thread_net(layer_list=layer_list, num_nets=num_nets)

loss = partial(pinball_loss_sum, h_cost=h_cost, l_cost=l_cost)
og_loss = partial(pinball_loss, h_cost=h_cost, l_cost=l_cost)
loss_tensor = partial(pinball_loss_tensor, h_cost=h_cost, l_cost=l_cost)
optimizer = torch.optim.Adam(net_1.parameters(), lr=0.001)

train_losses, val_losses = train(net_1, optimizer, loss, train_loader, val_loader, epochs=num_epochs, eval_interval=10, device="cpu", use_one_cycle_lr=True)

test_loss = get_test_loss(net_1, test_loader, og_loss, "cpu")
# Out:
# Training: 100%|██████████| 500/500 [02:02<00:00,  4.10step/s, train_loss=37472.7031]

# %%
# Loss curves for thread_net (split) vs net_2 are plotted in the cell after `net_2` is trained.

# %%
test_data = test_loader.dataset.x
test_y = test_loader.dataset.y
test_y_hat = net_1(test_data)
test_loss_tensor_1 = loss_tensor(test_y_hat, test_y)
# Per (store, item) mean pinball over test rows; columns are store-major (store_1_item_1 … store_1_item_50, …)
loss_per_col = test_loss_tensor_1.mean(dim=0).detach().cpu().numpy()
n_stores, n_items = 10, 50

# %%
# Mean test pinball loss per target column, greatest to least
ranked = sorted(
    zip(test_loader.dataset.y_columns, loss_per_col),
    key=lambda t: t[1],
    reverse=True,
)
for col, loss_val in ranked:
    print(col, loss_val)
# Out:
# next_store_2_item_18 22.658829
# next_store_3_item_13 22.140968
# next_store_2_item_45 22.092594
# next_store_8_item_22 21.938581
# next_store_8_item_18 21.875805
# next_store_8_item_28 21.696312
# next_store_2_item_15 21.595886
# next_store_4_item_28 21.438898
# next_store_2_item_13 21.180748
# next_store_8_item_15 21.003273
# next_store_2_item_25 20.969852
# next_store_2_item_10 20.95263
# next_store_2_item_36 20.929173
# next_store_2_item_28 20.919231
# next_store_10_item_13 20.84877
# next_store_3_item_10 20.605194
# next_store_4_item_18 20.457615
# next_store_8_item_25 20.302492
# next_store_3_item_25 20.171158
# next_store_9_item_15 20.100643
# next_store_4_item_45 20.098537
# next_store_9_item_13 20.001978
# next_store_3_item_22 19.98143
# next_store_3_item_8 19.842985
# next_store_9_item_18 19.769377
# next_store_2_item_8 19.734999
# next_store_3_item_18 19.717823
# next_store_10_item_22 19.71533
# next_store_8_item_33 19.70392
# next_store_4_item_25 19.690903
# next_store_10_item_18 19.483402
# next_store_10_item_15 19.475552
# next_store_10_item_25 19.460135
# next_store_8_item_36 19.37456
# next_store_8_item_8 19.36932
# next_store_3_item_38 19.363901
# next_store_4_item_13 19.314634
# next_store_10_item_28 19.304026
# next_store_10_item_45 19.252295
# next_store_3_item_36 19.245564
# next_store_2_item_12 19.191286
# next_store_2_item_29 19.168373
# next_store_3_item_28 19.147865
# next_store_2_item_38 18.897057
# next_store_4_item_15 18.892525
# next_store_9_item_10 18.844578
# next_store_8_item_12 18.82195
# next_store_10_item_38 18.803617
# next_store_3_item_15 18.797215
# next_store_1_item_38 18.794254
# next_store_1_item_28 18.775946
# next_store_2_item_50 18.770721
# next_store_8_item_35 18.76087
# next_store_9_item_28 18.740175
# next_store_2_item_22 18.700655
# next_store_8_item_45 18.653986
# next_store_4_item_36 18.593685
# next_store_3_item_45 18.585627
# next_store_9_item_36 18.533411
# next_store_8_item_13 18.522293
# next_store_10_item_36 18.451426
# next_store_9_item_25 18.444277
# next_store_8_item_10 18.441963
# next_store_10_item_12 18.429153
# next_store_2_item_35 18.330168
# next_store_10_item_8 18.274483
# next_store_8_item_38 18.26828
# next_store_9_item_8 18.26365
# next_store_9_item_38 18.191872
# next_store_3_item_11 18.1427
# next_store_3_item_24 18.131544
# next_store_2_item_33 18.119936
# next_store_2_item_11 18.110289
# next_store_8_item_14 18.055464
# next_store_2_item_24 18.018774
# next_store_3_item_35 17.92266
# next_store_1_item_15 17.872305
# next_store_10_item_33 17.798223
# next_store_8_item_29 17.76782
# next_store_8_item_6 17.682814
# next_store_4_item_8 17.630497
# next_store_2_item_2 17.620762
# next_store_4_item_29 17.62029
# next_store_2_item_46 17.611708
# next_store_8_item_7 17.592735
# next_store_4_item_10 17.518616
# next_store_4_item_38 17.507713
# next_store_9_item_29 17.47831
# next_store_9_item_45 17.445564
# next_store_2_item_31 17.435709
# next_store_3_item_12 17.419455
# next_store_10_item_11 17.381145
# next_store_2_item_6 17.367878
# next_store_8_item_11 17.357569
# next_store_5_item_15 17.302946
# next_store_10_item_29 17.272884
# next_store_9_item_22 17.21753
# next_store_8_item_31 17.20821
# next_store_2_item_7 17.190077
# next_store_6_item_28 17.171116
# next_store_3_item_33 17.161022
# next_store_8_item_43 17.143303
# next_store_1_item_18 17.102213
# next_store_4_item_50 17.09011
# next_store_8_item_50 17.070389
# next_store_1_item_22 17.065407
# next_store_10_item_10 17.050455
# next_store_6_item_13 17.036491
# next_store_1_item_8 17.00711
# next_store_9_item_12 16.932713
# next_store_2_item_14 16.928497
# next_store_1_item_10 16.920328
# next_store_6_item_15 16.876688
# next_store_1_item_36 16.842854
# next_store_8_item_24 16.771084
# next_store_8_item_2 16.763302
# next_store_5_item_13 16.76233
# next_store_4_item_12 16.752686
# next_store_4_item_11 16.730633
# next_store_4_item_24 16.700338
# next_store_4_item_22 16.635899
# next_store_10_item_50 16.634706
# next_store_10_item_24 16.52816
# next_store_3_item_29 16.450083
# next_store_2_item_32 16.425032
# next_store_9_item_11 16.40639
# next_store_6_item_18 16.364529
# next_store_9_item_7 16.338633
# next_store_8_item_9 16.333374
# next_store_1_item_13 16.317402
# next_store_4_item_35 16.26453
# next_store_10_item_46 16.231504
# next_store_9_item_33 16.182234
# next_store_3_item_2 16.132223
# next_store_8_item_48 16.051975
# next_store_3_item_6 16.043482
# next_store_8_item_46 15.971698
# next_store_9_item_24 15.971026
# next_store_7_item_22 15.959659
# next_store_9_item_35 15.953341
# next_store_3_item_50 15.856245
# next_store_1_item_45 15.849484
# next_store_1_item_25 15.828539
# next_store_5_item_25 15.822284
# next_store_2_item_9 15.783281
# next_store_8_item_26 15.663027
# next_store_10_item_43 15.632443
# next_store_3_item_46 15.625307
# next_store_9_item_6 15.622801
# next_store_4_item_33 15.602727
# next_store_5_item_28 15.567322
# next_store_10_item_2 15.559611
# next_store_5_item_8 15.451806
# next_store_4_item_7 15.426091
# next_store_5_item_38 15.417939
# next_store_10_item_35 15.404732
# next_store_9_item_50 15.3922415
# next_store_6_item_38 15.37832
# next_store_5_item_18 15.36301
# next_store_1_item_24 15.316898
# next_store_6_item_45 15.316105
# next_store_10_item_6 15.315536
# next_store_10_item_7 15.234553
# next_store_3_item_14 15.212381
# next_store_4_item_6 15.197799
# next_store_6_item_22 15.187548
# next_store_10_item_48 15.184223
# next_store_2_item_43 15.145359
# next_store_4_item_9 15.127032
# next_store_7_item_13 15.119534
# next_store_10_item_14 15.098683
# next_store_9_item_14 15.083197
# next_store_7_item_28 15.082899
# next_store_9_item_31 15.078249
# next_store_3_item_48 15.073033
# next_store_8_item_32 15.070771
# next_store_3_item_31 15.066068
# next_store_6_item_25 15.006326
# next_store_10_item_9 15.0016575
# next_store_9_item_2 14.949993
# next_store_7_item_45 14.911912
# next_store_5_item_36 14.895557
# next_store_1_item_12 14.885078
# next_store_2_item_26 14.870146
# next_store_1_item_11 14.860497
# next_store_1_item_35 14.823027
# next_store_5_item_22 14.814751
# next_store_1_item_33 14.81402
# next_store_5_item_24 14.79894
# next_store_1_item_50 14.766335
# next_store_1_item_29 14.764283
# next_store_4_item_46 14.704827
# next_store_4_item_2 14.690804
# next_store_7_item_25 14.687028
# next_store_10_item_31 14.628975
# next_store_5_item_45 14.623773
# next_store_2_item_48 14.540014
# next_store_8_item_20 14.525746
# next_store_9_item_46 14.5108385
# next_store_2_item_30 14.501321
# next_store_7_item_18 14.443352
# next_store_6_item_36 14.440691
# next_store_1_item_14 14.4124975
# next_store_6_item_10 14.3770895
# next_store_7_item_38 14.354776
# next_store_2_item_21 14.354561
# next_store_4_item_48 14.268013
# next_store_3_item_26 14.25736
# next_store_7_item_15 14.164722
# next_store_9_item_48 14.138595
# next_store_5_item_11 14.138282
# next_store_5_item_29 14.106851
# next_store_9_item_43 14.100763
# next_store_4_item_14 14.089419
# next_store_4_item_43 14.086546
# next_store_3_item_7 14.068517
# next_store_6_item_8 14.050452
# next_store_2_item_20 14.048132
# next_store_8_item_39 14.031972
# next_store_3_item_20 14.030292
# next_store_1_item_2 14.01159
# next_store_5_item_10 14.003341
# next_store_9_item_9 13.968065
# next_store_7_item_36 13.957442
# next_store_7_item_10 13.921715
# next_store_6_item_29 13.85142
# next_store_6_item_24 13.80675
# next_store_6_item_11 13.784636
# next_store_2_item_39 13.75733
# next_store_5_item_50 13.750277
# next_store_4_item_39 13.743936
# next_store_8_item_21 13.729534
# next_store_10_item_20 13.729193
# next_store_3_item_32 13.697897
# next_store_3_item_43 13.663652
# next_store_4_item_20 13.538421
# next_store_1_item_46 13.530667
# next_store_5_item_33 13.523506
# next_store_7_item_33 13.458358
# next_store_4_item_31 13.447986
# next_store_8_item_19 13.441866
# next_store_10_item_30 13.426259
# next_store_1_item_20 13.383742
# next_store_2_item_42 13.366182
# next_store_9_item_39 13.323241
# next_store_1_item_39 13.279556
# next_store_1_item_7 13.278967
# next_store_10_item_19 13.2166195
# next_store_6_item_12 13.174078
# next_store_9_item_26 13.159475
# next_store_8_item_42 13.152459
# next_store_4_item_30 13.146114
# next_store_5_item_31 13.1438465
# next_store_10_item_26 13.134838
# next_store_2_item_19 13.134171
# next_store_6_item_33 13.1270485
# next_store_8_item_3 13.051309
# next_store_3_item_39 13.030632
# next_store_1_item_43 13.020174
# next_store_5_item_12 13.01163
# next_store_6_item_35 12.987408
# next_store_3_item_9 12.970017
# next_store_7_item_50 12.898767
# next_store_4_item_32 12.848751
# next_store_1_item_31 12.833977
# next_store_3_item_30 12.818179
# next_store_9_item_20 12.78021
# next_store_4_item_21 12.766352
# next_store_6_item_50 12.759675
# next_store_7_item_8 12.75715
# next_store_10_item_32 12.730524
# next_store_7_item_35 12.717826
# next_store_7_item_29 12.660423
# next_store_5_item_2 12.660168
# next_store_5_item_14 12.637882
# next_store_10_item_21 12.616165
# next_store_2_item_3 12.603361
# next_store_7_item_24 12.593002
# next_store_6_item_2 12.5806465
# next_store_1_item_9 12.548401
# next_store_7_item_12 12.538376
# next_store_4_item_26 12.505682
# next_store_7_item_11 12.473016
# next_store_5_item_35 12.385741
# next_store_2_item_23 12.373738
# next_store_5_item_9 12.358769
# next_store_6_item_14 12.355989
# next_store_9_item_32 12.335292
# next_store_2_item_17 12.29921
# next_store_9_item_30 12.290988
# next_store_10_item_3 12.288976
# next_store_1_item_6 12.242314
# next_store_5_item_7 12.230209
# next_store_1_item_48 12.161744
# next_store_10_item_39 12.147099
# next_store_3_item_21 12.083547
# next_store_5_item_6 12.080799
# next_store_3_item_19 12.044957
# next_store_4_item_19 12.002225
# next_store_9_item_42 11.980549
# next_store_1_item_26 11.976397
# next_store_4_item_3 11.9520235
# next_store_3_item_42 11.941647
# next_store_5_item_46 11.907938
# next_store_3_item_3 11.85384
# next_store_7_item_46 11.787972
# next_store_6_item_31 11.736758
# next_store_6_item_7 11.727382
# next_store_7_item_31 11.722756
# next_store_9_item_21 11.721394
# next_store_8_item_30 11.7123
# next_store_7_item_14 11.579745
# next_store_6_item_46 11.567915
# next_store_9_item_19 11.518015
# next_store_4_item_42 11.387109
# next_store_8_item_23 11.37997
# next_store_2_item_44 11.378735
# next_store_9_item_17 11.339663
# next_store_2_item_40 11.334774
# next_store_6_item_43 11.225609
# next_store_7_item_6 11.173307
# next_store_7_item_9 11.149806
# next_store_3_item_40 11.111057
# next_store_5_item_26 11.07979
# next_store_8_item_17 11.072394
# next_store_1_item_32 11.071226
# next_store_6_item_6 11.069243
# next_store_10_item_42 11.066323
# next_store_3_item_49 11.024774
# next_store_5_item_39 11.002627
# next_store_10_item_17 10.972858
# next_store_1_item_21 10.961336
# next_store_5_item_43 10.870935
# next_store_7_item_7 10.853644
# next_store_7_item_48 10.838306
# next_store_3_item_17 10.808984
# next_store_7_item_2 10.807874
# next_store_5_item_48 10.790056
# next_store_1_item_30 10.775748
# next_store_8_item_37 10.76579
# next_store_7_item_26 10.743578
# next_store_9_item_49 10.701846
# next_store_6_item_32 10.69371
# next_store_6_item_20 10.635128
# next_store_3_item_44 10.625853
# next_store_6_item_9 10.613662
# next_store_2_item_34 10.609767
# next_store_4_item_44 10.59712
# next_store_2_item_49 10.596876
# next_store_2_item_37 10.564021
# next_store_5_item_32 10.533084
# next_store_9_item_23 10.526241
# next_store_4_item_17 10.511038
# next_store_1_item_3 10.503571
# next_store_1_item_19 10.450372
# next_store_2_item_16 10.4444475
# next_store_7_item_43 10.4199
# next_store_5_item_20 10.407693
# next_store_6_item_48 10.39793
# next_store_1_item_37 10.384878
# next_store_8_item_1 10.376674
# next_store_10_item_49 10.3486
# next_store_8_item_49 10.343947
# next_store_6_item_26 10.339315
# next_store_9_item_3 10.280711
# next_store_7_item_20 10.273044
# next_store_7_item_39 10.24613
# next_store_8_item_40 10.219565
# next_store_10_item_23 10.193634
# next_store_5_item_21 10.163556
# next_store_8_item_16 10.125789
# next_store_3_item_34 10.118281
# next_store_3_item_23 10.099302
# next_store_7_item_42 10.065565
# next_store_10_item_40 10.048271
# next_store_10_item_37 10.022801
# next_store_7_item_32 10.011257
# next_store_4_item_37 9.942439
# next_store_9_item_40 9.920261
# next_store_1_item_42 9.901912
# next_store_8_item_34 9.808925
# next_store_5_item_30 9.796499
# next_store_4_item_40 9.7783985
# next_store_5_item_19 9.745752
# next_store_9_item_37 9.738967
# next_store_8_item_44 9.685057
# next_store_6_item_3 9.677081
# next_store_10_item_47 9.673194
# next_store_8_item_41 9.66076
# next_store_6_item_39 9.614323
# next_store_7_item_30 9.611826
# next_store_6_item_30 9.594989
# next_store_5_item_3 9.581573
# next_store_9_item_44 9.575665
# next_store_3_item_37 9.568692
# next_store_2_item_27 9.56857
# next_store_6_item_21 9.539322
# next_store_2_item_1 9.531769
# next_store_9_item_16 9.472557
# next_store_8_item_4 9.454132
# next_store_4_item_49 9.449958
# next_store_3_item_16 9.445517
# next_store_6_item_42 9.426839
# next_store_2_item_4 9.413432
# next_store_4_item_23 9.3913555
# next_store_3_item_27 9.334148
# next_store_7_item_19 9.296648
# next_store_1_item_40 9.280061
# next_store_1_item_44 9.232871
# next_store_8_item_47 9.229088
# next_store_4_item_34 9.219757
# next_store_6_item_19 9.160047
# next_store_1_item_16 9.157061
# next_store_1_item_23 9.149905
# next_store_9_item_34 9.136825
# next_store_7_item_3 9.125544
# next_store_10_item_44 9.119656
# next_store_2_item_41 9.100707
# next_store_5_item_17 9.053786
# next_store_6_item_17 9.017432
# next_store_9_item_41 9.012362
# next_store_2_item_47 9.004742
# next_store_4_item_41 8.997721
# next_store_10_item_4 8.952369
# next_store_7_item_17 8.9286
# next_store_8_item_27 8.834095
# next_store_1_item_17 8.833755
# next_store_10_item_41 8.830256
# next_store_10_item_16 8.813714
# next_store_10_item_34 8.787206
# next_store_9_item_4 8.734399
# next_store_5_item_42 8.700928
# next_store_3_item_41 8.67625
# next_store_2_item_5 8.651084
# next_store_3_item_1 8.646637
# next_store_4_item_16 8.600163
# next_store_7_item_21 8.483784
# next_store_5_item_40 8.473763
# next_store_4_item_1 8.472465
# next_store_1_item_49 8.443489
# next_store_3_item_4 8.428834
# next_store_6_item_44 8.423094
# next_store_5_item_44 8.393216
# next_store_5_item_49 8.293011
# next_store_7_item_49 8.227205
# next_store_9_item_1 8.219589
# next_store_6_item_40 8.188883
# next_store_6_item_49 8.178471
# next_store_4_item_47 8.162386
# next_store_3_item_47 8.079989
# next_store_9_item_47 8.066357
# next_store_10_item_1 8.017855
# next_store_10_item_27 8.00803
# next_store_4_item_27 7.997257
# next_store_10_item_5 7.997175
# next_store_5_item_23 7.9662833
# next_store_7_item_40 7.8669105
# next_store_1_item_27 7.844496
# next_store_8_item_5 7.838845
# next_store_5_item_34 7.7888236
# next_store_6_item_34 7.7507358
# next_store_9_item_27 7.7164664
# next_store_4_item_5 7.6740932
# next_store_3_item_5 7.6591086
# next_store_5_item_37 7.6565285
# next_store_6_item_37 7.6560316
# next_store_1_item_34 7.6497765
# next_store_1_item_4 7.646731
# next_store_7_item_44 7.611628
# next_store_1_item_41 7.591434
# next_store_6_item_4 7.571942
# next_store_5_item_47 7.5683913
# next_store_7_item_16 7.556258
# next_store_7_item_23 7.547974
# next_store_6_item_23 7.544085
# next_store_1_item_47 7.539231
# next_store_7_item_37 7.528294
# next_store_9_item_5 7.407777
# next_store_6_item_41 7.4045806
# next_store_1_item_1 7.334079
# next_store_6_item_27 7.283678
# next_store_6_item_16 7.247321
# next_store_4_item_4 7.247164
# next_store_5_item_27 7.110927
# next_store_7_item_41 6.950692
# next_store_7_item_34 6.894174
# next_store_5_item_41 6.854938
# next_store_7_item_27 6.778346
# next_store_7_item_4 6.7386727
# next_store_5_item_16 6.656801
# next_store_1_item_5 6.51175
# next_store_6_item_47 6.5110044
# next_store_6_item_5 6.482603
# next_store_5_item_5 6.4706216
# next_store_5_item_1 6.402543
# next_store_7_item_47 6.2214518
# next_store_5_item_4 6.189705
# next_store_7_item_1 6.1791143
# next_store_7_item_5 5.9337163
# next_store_6_item_1 5.8264155

# %% [markdown]
# Compare with normal lr thread net

# %%
net_2 = thread_net(layer_list=layer_list, num_nets=num_nets)
optimizer_1 = torch.optim.Adam(net_2.parameters(), lr=0.001)
train_losses_2, val_losses_2 = train(net_2, optimizer_1, loss, train_loader, val_loader, epochs=num_epochs, eval_interval=10, device="cpu")
test_loss_2 = get_test_loss(net_2, test_loader, og_loss, "cpu")
# Out:
# Training: 100%|██████████| 500/500 [01:56<00:00,  4.27step/s, train_loss=45509.3398]

# %%
def _stats(a):
    t = torch.tensor(a, dtype=torch.float32)
    return t.mean().item(), t.min().item(), t.max().item()


fig, axs = plt.subplots(3, 2, figsize=(12, 10))

m, lo, hi = _stats(train_losses)
axs[0, 0].plot(train_losses)
axs[0, 0].set_title(f"Train — OneCycleLR (pct0.2, div10)\nmean={m:.4f}, min={lo:.4f}, max={hi:.4f}")
m, lo, hi = _stats(val_losses)
axs[1, 0].plot(val_losses)
axs[1, 0].set_title(f"Validation — OneCycleLR (pct0.2, div10)\nmean={m:.4f}, min={lo:.4f}, max={hi:.4f}")
m, lo, hi = _stats(test_loss)
axs[2, 0].plot(test_loss)
axs[2, 0].set_title(f"Test — OneCycleLR (pct0.2, div10)\nmean={m:.4f}, min={lo:.4f}, max={hi:.4f}")

m, lo, hi = _stats(train_losses_2)
axs[0, 1].plot(train_losses_2)
axs[0, 1].set_title(f"Train — fixed LR (Adam lr=0.001, no OneCycle)\nmean={m:.4f}, min={lo:.4f}, max={hi:.4f}")
m, lo, hi = _stats(val_losses_2)
axs[1, 1].plot(val_losses_2)
axs[1, 1].set_title(f"Validation — fixed LR (Adam lr=0.001, no OneCycle)\nmean={m:.4f}, min={lo:.4f}, max={hi:.4f}")
m, lo, hi = _stats(test_loss_2)
axs[2, 1].plot(test_loss_2)
axs[2, 1].set_title(f"Test — fixed LR (Adam lr=0.001, no OneCycle)\nmean={m:.4f}, min={lo:.4f}, max={hi:.4f}")

for ax in axs.flat:
    ax.set_xlabel("step / batch index")
    ax.set_ylabel("loss")
fig.suptitle("Pinball loss: OneCycleLR vs fixed LR (both thread_net)", y=1.02)
plt.tight_layout()
plt.show()

# %%
test_y_hat_2 = net_2(test_data)
test_loss_tensor_2 = loss_tensor(test_y_hat_2, test_y)
loss_per_col_2 = test_loss_tensor_2.mean(dim=0).detach().cpu().numpy()

loss_matrix = loss_per_col.reshape(n_stores, n_items)
loss_matrix_2 = loss_per_col_2.reshape(n_stores, n_items)

vmin = float(min(loss_matrix.min(), loss_matrix_2.min()))
vmax = float(max(loss_matrix.max(), loss_matrix_2.max()))

fig, axes = plt.subplots(2, 1, figsize=(16, 10))
for ax, M, name in (
    (axes[0], loss_matrix, "thread_net (split)"),
    (axes[1], loss_matrix_2, "net_2 (simple_net)"),
):
    im = ax.imshow(M, aspect="auto", cmap="viridis", vmin=vmin, vmax=vmax)
    ax.set_xlabel("Item index (1–50 within store)")
    ax.set_ylabel("Store index (1–10)")
    ax.set_title(
        f"{name} — mean={M.mean():.4f}, min={M.min():.4f}, max={M.max():.4f}"
    )
    plt.colorbar(im, ax=ax, label="mean pinball loss (test)")
    ax.set_xticks(np.arange(0, n_items, 5))
    ax.set_yticks(np.arange(n_stores))
plt.suptitle("Mean test pinball loss per (store, item)", y=1.02)
plt.tight_layout()
plt.show()

# %%
print(np.sum(loss_matrix > loss_matrix_2))
print(np.mean(loss_matrix - loss_matrix_2))
print(np.sum(loss_matrix < loss_matrix_2))
# Out:
# 184
# -0.60278684
# 316
